# %% [markdown]
# ## Q러닝 구현

# %%
# 구현에 사용할 패키지 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 상태를 의미하는 문자열(S0~S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 정책을 결정하는 파라미터의 초깃값 theta_0를 설정

# 줄은 상태 0~7, 열은 행동방향(상,우,하,좌 순)를 나타낸다
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8은 목표지점이므로 정책이 없다
                    ])

# %%
# 정책 파라미터 theta_0을 무작위 행동 정책 pi로 변환하는 함수


def simple_convert_into_pi_from_theta(theta):
    '''단순 비율 계산'''

    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 비율 계산

    pi = np.nan_to_num(pi)  # nan을 0으로 변환

    return pi

# 무작위 행동정책 pi_0을 계산
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 행동가치 함수 Q의 초기 상태

[a, b] = theta_0.shape  # # 열과 행의 갯수를 변수 a, b에 저장
Q = np.random.rand(a, b) * theta_0 * 0.1
# * theta0 로 요소 단위 곱셈을 수행, Q에서 벽 방향으로 이동하는 행동에는 nan을 부여

# %%
# ε-greedy 알고리즘 구현


def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    """
    # 행동을 결정
    if np.random.rand() < epsilon:
        # 확률 ε로 무작위 행동을 선택함
        next_direction = "up"
    else:
        # Q값이 최대가 되는 행동을 선택함
        next_direction = "up"
    """

    # 행동을 인덱스로 변환
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action


def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 행동 a의 방향

    # 행동으로 다음 상태를 결정
    if next_direction == "up":
        s_next = s - 3  # 위로 이동하면 상태값이 3 줄어든다
    elif next_direction == "right":
        s_next = s + 1  # 오른쪽으로 이동하면 상태값이 1 늘어난다
    elif next_direction == "down":
        s_next = s + 3  # 아래로 이동하면 상태값이 3 늘어난다
    elif next_direction == "left":
        s_next = s - 1  # 왼쪽으로 이동하면 상태값이 1 줄어든다

    return s_next

# %%
# Q러닝 알고리즘으로 행동가치 함수 Q를 수정


def Q_learning(s, a, r, s_next, Q, alpha, gamma):

    if s_next == 8:  # 목표 지점에 도달한 경우
        Q[s, a] = Q[s, a] + alpha * (r - Q[s, a])
    """
    else:   # Q-leaning Q function 업데이트 식 참조
        Q[s, a] = 0
    """
    return Q

# %%
# Q러닝 알고리즘으로 미로를 빠져나오는 함수, 상태 및 행동 그리고 Q값의 히스토리를 출력한다


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # 시작 지점
    a = a_next = get_action(s, Q, epsilon, pi)  # 첫 번째 행동
    s_a_history = [[0, np.nan]]  # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트

    while (1):  # 목표 지점에 이를 때까지 반복
        a = a_next  # 행동 결정

        s_a_history[-1][1] = a
        # 현재 상태(마지막으로 인덱스가 -1)을 히스토리에 추가

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 다음 단계의 상태를 구함

        s_a_history.append([s_next, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둔다

        # 보상을 부여하고 다음 행동을 계산함
        if s_next == 8:
            r = 1  # 목표 지점에 도달했다면 보상을 부여
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 다음 행동 a_next를 계산

        # 가치함수를 수정
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 종료 여부 판정
        if s_next == 8:  # 목표 지점에 도달하면 종료
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Q러닝 알고리즘으로 미로 빠져나오기

eta = 0.1  # 학습률
gamma = 0.9  # 시간할인율
epsilon = 0.5  # ε-greedy 알고리즘 epsilon 초깃값
v = np.nanmax(Q, axis=1)  # 각 상태마다 가치의 최댓값을 계산
is_continue = True
episode = 1

V = []  # 에피소드 별로 상태가치를 저장
V.append(np.nanmax(Q, axis=1))  # 상태 별로 행동가치의 최댓값을 계산

while is_continue:  # is_continue의 값이 False가 될 때까지 반복
    print("에피소드: " + str(episode))

    # ε 값을 조금씩 감소시킴
    epsilon = epsilon / 2

    # Q러닝으로 미로를 빠져나온 후, 결과로 나온 행동 히스토리와 Q값을 변수에 저장
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 상태가치의 변화
    new_v = np.nanmax(Q, axis=1)  # 각 상태마다 행동가치의 최댓값을 계산
    print(np.sum(np.abs(new_v - v)))  # 상태가치 함수의 변화를 출력
    v = new_v
    V.append(v)  # 현재 에피소드가 끝난 시점의 상태가치 함수를 추가

    print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")

    # 100 에피소드 반복
    episode = episode + 1
    if episode > 100:
        break
# Out:
# 에피소드: 1
# 0.18263018412863255
# 목표 지점에 이르기까지 걸린 단계 수는 140단계입니다
# 에피소드: 2
# 0.12546842301702632
# 목표 지점에 이르기까지 걸린 단계 수는 96단계입니다
# 에피소드: 3
# 0.09605942089961848
# 목표 지점에 이르기까지 걸린 단계 수는 90단계입니다
# 에피소드: 4
# 0.09621344321519817
# 목표 지점에 이르기까지 걸린 단계 수는 52단계입니다
# 에피소드: 5
# 0.09065307200656295
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다
# 에피소드: 6
# 0.08940976206619841
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 7
# 0.0884448973862543
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 8
# 0.08746281052638648
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 9
# 0.08644715452803783
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 10
# 0.08538407302938289
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 11
# 0.08426235021933559
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 12
# 0.08307341848420395
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 13
# 0.08181126334499786
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 14
# 0.0804722571337656
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 15
# 0.07905494614589921
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 16
# 0.07755981050166398
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 17
# 0.07598901145832726
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 18
# 0.07434613726787015
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 19
# 0.07263595573338921
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 20
# 0.07086417926069327
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 21
# 0.06903724632952493
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 22
# 0.06716212183643352
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 23
# 0.06524611761717455
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 24
# 0.0632967335807155
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 25
# 0.061321519229346255
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 26
# 0.059327954858166054
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 27
# 0.05732335138751307
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 28
# 0.05531476755482659
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 29
# 0.0533089430541
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 30
# 0.05131224614184843
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 31
# 0.04933063421225509
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 32
# 0.047369625867768994
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 33
# 0.045434283064243686
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 34
# 0.043529201983188825
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 35
# 0.04165851137100979
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 36
# 0.03982587718082797
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 37
# 0.03803451245240247
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 38
# 0.036287191466518764
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 39
# 0.03458626730956632
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 40
# 0.03293369208002239
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 41
# 0.03133103905993523
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 42
# 0.029779526260370726
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 43
# 0.028280040829588182
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 44
# 0.02683316388618412
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 45
# 0.025439195406481818
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 46
# 0.02409817885612975
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 47
# 0.02280992531038517
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 48
# 0.021574036856171985
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 49
# 0.02038992911202897
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 50
# 0.01925685273988431
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 51
# 0.018173913855576984
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 52
# 0.017140093273581236
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 53
# 0.016154264545888974
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 54
# 0.015215210775819554
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 55
# 0.014321640205049224
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 56
# 0.013472200586709171
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 57
# 0.012665492369346443
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 58
# 0.011900080726148676
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 59
# 0.011174506471422596
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 60
# 0.010487295912113392
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 61
# 0.009836969686415453
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 62
# 0.009222050644466906
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 63
# 0.008641070827923869
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 64
# 0.008092577606066742
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 65
# 0.007575139026138489
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 66
# 0.0070873484350056914
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 67
# 0.006627828428076854
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 68
# 0.006195234179828701
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 69
# 0.005788256208356879
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 70
# 0.005405622624182094
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 71
# 0.005046100911160534
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 72
# 0.004708499284835854
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 73
# 0.004391667670980981
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 74
# 0.004094498344447528
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 75
# 0.003815926265812397
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 76
# 0.0035549291507093184
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 77
# 0.003310527304184019
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 78
# 0.00308178324993158
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 79
# 0.002867801181888452
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 80
# 0.002667726263351544
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 81
# 0.00248074379661245
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 82
# 0.002306078284023183
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 83
# 0.0021429923994429334
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 84
# 0.0019907858871791584
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 85
# 0.0018487944038062532
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 86
# 0.001716388316639672
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 87
# 0.0015929714711444554
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 88
# 0.0014779799381721137
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 89
# 0.0013708807506416232
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 90
# 0.001271170638103003
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 91
# 0.0011783747665446986
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 92
# 0.0010920454898166732
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 93
# 0.0010117611181449382
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 94
# 0.0009371247083980183
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 95
# 0.0008677628800235482
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 96
# 0.0008033246599128407
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 97
# 0.0007434803588447503
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 98
# 0.000687920481634241
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 99
# 0.0006363546726194658
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 100
# 0.000588510697710598
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다

# %%
# 상태가치의 변화를 시각화
# 참고 URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 배경색 초기화
    line.set_data([], [])
    return (line,)


def animate(i):
    # 프레임 단위로 그림을 그림
    # 각 칸에 상태가치 값으로 결정된 색을 칠함
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S8
    return (line,)


# 초기화 함수와 프레임 단위로 그림을 그리는 함수로 애니메이션을 생성
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img83b3262936e84cc5a4ae714ff0507eab">
#   <div class="anim-controls">
#     <input id="_anim_slider83b3262936e84cc5a4ae714ff0507eab" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim83b3262936e84cc5a4ae714ff0507eab.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim83b3262936e84cc5a4ae714ff0507eab.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim83b3262936e84cc5a4ae714ff0507eab.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim83b3262936e84cc5a4ae714ff0507eab.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim83b3262936e84cc5a4ae714ff0507eab.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim83b3262936e84cc5a4ae714ff0507eab.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim83b3262936e84cc5a4ae714ff0507eab.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim83b3262936e84cc5a4ae714ff0507eab.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim83b3262936e84cc5a4ae714ff0507eab.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim83b3262936e84cc5a4ae714ff0507eab.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select83b3262936e84cc5a4ae714ff0507eab"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_83b3262936e84cc5a4ae714ff0507eab"
#              checked>
#       <label for="_anim_radio1_83b3262936e84cc5a4ae714ff0507eab">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_83b3262936e84cc5a4ae714ff0507eab"
#              >
#       <label for="_anim_radio2_83b3262936e84cc5a4ae714ff0507eab">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_83b3262936e84cc5a4ae714ff0507eab"
#              >
#       <label for="_anim_radio3_83b3262936e84cc5a4ae714ff0507eab">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img83b3262936e84cc5a4ae714ff0507eab";
#     var slider_id = "_anim_slider83b3262936e84cc5a4ae714ff0507eab";
#     var loop_select_id = "_anim_loop_select83b3262936e84cc5a4ae714ff0507eab";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8pXeV/AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAiX0lE
