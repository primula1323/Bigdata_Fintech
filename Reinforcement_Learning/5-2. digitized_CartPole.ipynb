# %% [markdown]
# ## 다변수 연속값 상태를 이산변수로 변환하기

# %%
# 구현에 사용할 패키지 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 상수 정의
ENV = 'CartPole-v0'  # 태스크 이름
NUM_DIZITIZED = 6  # 각 상태를 이산변수로 변환할 구간 수

# %%
# CartPole 실행
env = gym.make(ENV)  # 태스크 실행 환경 생성
observation = env.reset()  # 환경 초기화
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
# 이산변수 변환에 사용할 구간을 계산

def bins(clip_min, clip_max, num):
    '''관측된 상태(연속값)을 이산값으로 변환하는 구간을 계산'''
    return np.linspace(clip_min, clip_max, num + 1)[1:-1]

# %%
np.linspace(-2.4, 2.4, 6 + 1)
# Out:
# array([-2.4, -1.6, -0.8,  0. ,  0.8,  1.6,  2.4])

# %%
np.linspace(-2.4, 2.4, 6 + 1)[1:-1]
# Out:
# array([-1.6, -0.8,  0. ,  0.8,  1.6])

# %%
def digitize_state(observation):
    '''관측된 상태(observation)을 이산값으로 변환 : 구간을 나눠 변환. 테이블 세계는 연속 처리 불가. '''
    cart_pos, cart_v, pole_angle, pole_v = observation
    digitized = [
        np.digitize(cart_pos, bins=bins(-2.4, 2.4, NUM_DIZITIZED)), #수직선상 카트 위치 
        np.digitize(cart_v, bins=bins(-3.0, 3.0, NUM_DIZITIZED)), #카트 속도 
        np.digitize(pole_angle, bins=bins(-0.5, 0.5, NUM_DIZITIZED)), #막대기의 각도 
        np.digitize(pole_v, bins=bins(-2.0, 2.0, NUM_DIZITIZED))] #막대기의 각속도 
    return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

# %%
digitize_state(observation)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 digitize_state(observation)
#
# Cell In[7], line 3, in digitize_state(observation)
#       1 def digitize_state(observation):
#       2     '''관측된 상태(observation)을 이산값으로 변환 : 구간을 나눠 변환. 테이블 세계는 연속 처리 불가. '''
# ----> 3     cart_pos, cart_v, pole_angle, pole_v = observation
#       4     digitized = [
#       5         np.digitize(cart_pos, bins=bins(-2.4, 2.4, NUM_DIZITIZED)), #수직선상 카트 위치
#       6         np.digitize(cart_v, bins=bins(-3.0, 3.0, NUM_DIZITIZED)), #카트 속도
#       7         np.digitize(pole_angle, bins=bins(-0.5, 0.5, NUM_DIZITIZED)), #막대기의 각도
#       8         np.digitize(pole_v, bins=bins(-2.0, 2.0, NUM_DIZITIZED))] #막대기의 각속도
#       9     return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])
#
# ValueError: not enough values to unpack (expected 4, got 2)
