# %% [markdown]
# ## Sarsa 알고리즘 구현하기

# %%
# 구현에 사용할 패키지 임포트하기
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 상태를 의미하는 문자열(S0~S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 정책을 결정하는 파라미터의 초깃값 theta_0를 설정

# 줄은 상태 0~7, 열은 행동방향(상,우,하,좌 순)를 나타낸다
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8은 목표지점이므로 정책이 없다
                    ])

# %%
# 정책 파라미터 theta_0을 무작위 행동 정책 pi로 변환하는 함수

def simple_convert_into_pi_from_theta(theta):
    '''단순 비율 계산'''

    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 비율 계산

    pi = np.nan_to_num(pi)  # nan을 0으로 변환

    return pi

# 무작위 행동정책 pi_0을 계산
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 행동가치 함수 Q의 초기 상태

[a, b] = theta_0.shape  # 열과 행의 갯수를 변수 a, b에 저장
Q = np.random.rand(a, b) * theta_0
# * theta0 로 요소 단위 곱셈을 수행, Q에서 벽 방향으로 이동하는 행동에는 nan을 부여

# %%
# ε-greedy 알고리즘 구현

def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 행동을 결정 : 기초 array 정의
    Qwona = np.zeros(4) #zeros인 1*4 array 생성
    for i in range(0, 4) :
        if not np.isnan(Q[s][i]) :
            Qwona[i] = Q[s][i]
        #해당 array에 Q값이 nan이 아닌 경우에만 해당 값 대입.
    if np.random.rand() < epsilon:
        # 확률 ε로 무작위 행동을 선택함
        while True :
            Qwonain = np.random.randint(4)
            if Qwona[Qwonain] != 0 :
                break
        next_direction = direction[Qwonain]
    else:
        # Q값이 최대가 되는 행동을 선택함
        next_direction = direction[np.argmax(Qwona)]
        ## 직접 코딩해서 제출! 엡실론-그리디를 안 할 때 얘기. Q-table을 보고 현재 스테이트에서 Q값이 가장 높은 액션 선택하기. 

    # 행동을 인덱스로 변환
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action


def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 행동 a의 방향

    # 행동으로 다음 상태를 결정
    if next_direction == "up":
        s_next = s - 3  # 위로 이동하면 상태값이 3 줄어든다
    elif next_direction == "right":
        s_next = s + 1  # 오른쪽으로 이동하면 상태값이 1 늘어난다
    elif next_direction == "down":
        s_next = s + 3  # 아래로 이동하면 상태값이 3 늘어난다
    elif next_direction == "left":
        s_next = s - 1  # 왼쪽으로 이동하면 상태값이 1 줄어든다

    return s_next

# %%
# Sarsa 알고리즘으로 행동가치 함수 Q를 수정

def Sarsa(s, a, r, s_next, a_next, Q, alpha, gamma): #s,a : given, r, s_next, a_next : 실행 후. 

    if s_next == 8:  # 목표 지점에 도달한 경우
        Q[s, a] = Q[s, a] + alpha * (r - Q[s, a])
    else:   # SARSA Q function 업데이트 식 참조 : '획득한 샘플로 Q 업데이트' 부분 참고해 실행. 재미있음. 밖으로 나가지 못한다는 제약 추가할 것. 
        Q[s, a] = Q[s, a] + alpha * (r + gamma * Q[s_next, a_next] - Q[s, a])
    return Q

# %%
# Sarsa 알고리즘으로 미로를 빠져나오는 함수, 상태 및 행동 그리고 Q값의 히스토리를 출력

def goal_maze_ret_s_a_Q(Q, epsilon, alpha, gamma, pi):
    s = 0  # 시작 지점
    a = a_next = get_action(s, Q, epsilon, pi)  # 첫 번째 행동
    s_a_history = [[0, np.nan]]  # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트

    while (1):  # 목표 지점에 이를 때까지 반복
        a = a_next  # 행동 결정

        s_a_history[-1][1] = a
        # 현재 상태(마지막이므로 인덱스가 -1)을 히스토리에 추가

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 다음 단계의 상태를 구함

        s_a_history.append([s_next, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둠

        # 보상을 부여하고 다음 행동을 계산
        if s_next == 8:
            r = 1  # 목표 지점에 도달했다면 보상을 부여
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 다음 행동 a_next를 계산

        # 가치함수를 수정
        Q = Sarsa(s, a, r, s_next, a_next, Q, alpha, gamma)

        # 종료 여부 판정
        if s_next == 8:  # 목표 지점에 도달하면 종료
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Sarsa 알고리즘으로 미로 빠져나오기

alpha = 0.1  # 학습률
gamma = 0.9  # 시간할인율
epsilon = 0.5  # ε-greedy 알고리즘 epsilon 초깃값
v = np.nanmax(Q, axis=1)  # 각 상태마다 가치의 최댓값을 계산
is_continue = True
episode = 1

while is_continue:  # is_continue의 값이 False가 될 때까지 반복
    print("에피소드: " + str(episode))

    # ε 값을 조금씩 감소시킴
    epsilon = epsilon / 2

    # Sarsa 알고리즘으로 미로를 빠져나온 후, 결과로 나온 행동 히스토리와 Q값을 변수에 저장
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, alpha, gamma, pi_0)

    # 상태가치의 변화
    new_v = np.nanmax(Q, axis=1)  # 각 상태마다 행동가치의 최댓값을 계산
    print(np.sum(np.abs(new_v - v)))  # 상태가치 함수의 변화를 출력
    v = new_v

    print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")

    # 100 에피소드 반복
    episode = episode + 1
    if episode > 100:
        break
# Out:
# 에피소드: 1
# 1.101810417054976
# 목표 지점에 이르기까지 걸린 단계 수는 216단계입니다
# 에피소드: 2
# 0.5544914747485388
# 목표 지점에 이르기까지 걸린 단계 수는 180단계입니다
# 에피소드: 3
# 0.0892193064040297
# 목표 지점에 이르기까지 걸린 단계 수는 14단계입니다
# 에피소드: 4
# 0.4860893385053967
# 목표 지점에 이르기까지 걸린 단계 수는 86단계입니다
# 에피소드: 5
# 0.05102656777044984
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 6
# 0.046569629728108686
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 7
# 0.04567434217476818
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 8
# 0.04517654553293188
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 9
# 0.04467464508081054
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 10
# 0.044156079005116644
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 11
# 0.04361098019884496
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 12
# 0.04303191828246167
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 13
# 0.04241363379187574
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 14
# 0.04175277362256402
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 15
# 0.04104763441591036
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 16
# 0.04029791864360266
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 17
# 0.03950450660819238
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 18
# 0.03866924636461383
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 19
# 0.03779476262126136
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 20
# 0.036884284951939295
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 21
# 0.03594149510122974
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 22
# 0.03497039276177738
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 23
# 0.03397517891446716
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 24
# 0.03296015562806248
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 25
# 0.03192964109414065
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 26
# 0.03088789861010638
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 27
# 0.02983907820450815
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 28
# 0.028787169614054253
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 29
# 0.02773596536189049
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 30
# 0.026689032744757146
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 31
# 0.02564969360694197
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 32
# 0.024621010856963443
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 33
# 0.023605780765105888
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 34
# 0.022606530163545968
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 35
# 0.021625517753741996
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 36
# 0.02066473880643349
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 37
# 0.019725932616887043
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 38
# 0.01881059215113723
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 39
# 0.017919975387352016
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 40
# 0.017055117919882234
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 41
# 0.016216846451821754
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 42
# 0.01540579285508803
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 43
# 0.01462240852519825
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 44
# 0.013866978801263197
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 45
# 0.013139637260480508
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 46
# 0.012440379730845441
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 47
# 0.011769077896209512
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 48
# 0.011125492394497338
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 49
# 0.010509285333156648
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 50
# 0.009920032166045867
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 51
# 0.00935723289327517
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 52
# 0.008820322560262661
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 53
# 0.008308681044733812
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 54
# 0.007821642130813156
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 55
# 0.007358501877968937
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 56
# 0.006918526299591665
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 57
# 0.006500958371602583
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 58
# 0.00610502439588434
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 59
# 0.005729939746668911
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 60
# 0.005374914030441658
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 61
# 0.005039155691568986
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 62
# 0.0047218760968490425
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 63
# 0.004422293132609112
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 64
# 0.004139634347949395
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 65
# 0.003873139677310622
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 66
# 0.0036220637748299866
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 67
# 0.0033856779919736457
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 68
# 0.00316327202877964
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 69
# 0.0029541552877356825
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 70
# 0.002757657957908499
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 71
# 0.002573131855462374
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 72
# 0.002399951045184645
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 73
# 0.002237512266095587
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 74
# 0.002085235182690215
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 75
# 0.0019425624818509846
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 76
# 0.0018089598339773305
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 77
# 0.00168391573546256
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 78
# 0.0015669412482492984
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 79
# 0.001457569650885282
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 80
# 0.0013553560142315346
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 81
# 0.001259876713788799
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 82
# 0.0011707288894802215
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 83
# 0.001087529862668024
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 84
# 0.0010099165192017923
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 85
# 0.0009375446663674181
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 86
# 0.0008700883707543072
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 87
# 0.0008072392832654263
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 88
# 0.0007487059567691245
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 89
# 0.0006942131612138747
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 90
# 0.0006435012004231133
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 91
# 0.0005963252342114922
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 92
# 0.0005524546089686888
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 93
# 0.0005116721993807527
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 94
# 0.00047377376354607037
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 95
# 0.0004385673133617818
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 96
# 0.0004058725017185294
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 97
# 0.00037552002773499904
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 98
# 0.000347351060994483
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 99
# 0.00032121668550244564
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 100
# 0.00029697736387335194
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
