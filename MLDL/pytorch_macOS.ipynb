# %% [markdown]
# # Install pytorch

# %% [markdown]
# pytorch는 3.12 python을 지원하지 않음. 3.9 or 3.11 활용

# %%
#conda
conda install pytorch::pytorch torchvision torchaudio -c pytorch
# Out:
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/PyTorch_311
#
#   added / updated specs:
#     - pytorch::pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pytorch-2.3.0              |         py3.11_0        56.6 MB  pytorch
#     torchaudio-2.3.0           |        py311_cpu         5.0 MB  pytorch
#     torchvision-0.18.0         |        py311_cpu         6.8 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        68.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   torchaudio         pytorch/osx-arm64::torchaudio-2.3.0-py311_cpu
#
# The following packages will be UPDATED:
#
# ...

# %%
#pip
# %pip3 install torch torchvision torchaudio

# %%
#install check
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.8020, 0.4304, 0.7577],
#         [0.1079, 0.8653, 0.8558],
#         [0.1329, 0.0136, 0.7363],
#         [0.2915, 0.5347, 0.4165],
#         [0.6409, 0.4408, 0.0025]])

# %% [markdown]
# # Basic pytorch
